# %% [markdown]
# # <span style='color:green'> <center>Entrega 1-Seasons, Races, Drivers, Constructors, Circuits and Qualifying.</center> </span>
# ### by: **Oliver Iñiguez..**

# %% [markdown]
# ## Bibliotecas.

# %%
import requests
import json
import pandas as pd
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# ## Seasons

# %%
seasons = {'season':[],
        'url':[]}
url = 'http://ergast.com/api/f1/seasons.json?limit=1000'
response = requests.get(url)
content = json.loads(response.content)
for item in content['MRData']['SeasonTable']['Seasons']:
        seasons['season'].append(int(item['season']))
        seasons['url'].append(item['url'])
        
pd.DataFrame(seasons).to_csv('SeasonsE1.csv' , index=False)

# %% [markdown]
# ## Races

# %%
races = {'season':[],
        'round':[],
        'raceid':[],
        'raceName':[],
        'circuitId':[],
        'latitud':[],
        'longitud':[],
        'country':[],
        'date':[],
        'url':[]}


for year in list(range(2010,2024)):
    url = 'http://ergast.com/api/f1/{}.json'
    response = requests.get(url.format(year))
    content = json.loads(response.content)
    for item in content['MRData']['RaceTable']['Races']:
        races['season'].append(int(item['season']))
        races['round'].append(int(item['round']))
        races['raceid'].append(item['season'] + '_' + item['round'])
        races['raceName'].append(item['raceName'])
        races['circuitId'].append(item['Circuit'].get('circuitId'))
        races['latitud'].append(float(item['Circuit'].get('Location').get('lat')))
        races['longitud'].append(float(item['Circuit'].get('Location').get('long')))
        races['country'].append(item['Circuit'].get('Location').get('country'))
        races['date'].append(pd.to_datetime(item['date']))
        races['url'].append(item['url'])

df = pd.DataFrame(races)        
pd.DataFrame(races).to_csv('RacesE1.csv' , index=False)
df
# Out:
#      season  round   raceid                  raceName    circuitId   latitud  \
# 0      2010      1   2010_1        Bahrain Grand Prix      bahrain  26.03250
# 1      2010      2   2010_2     Australian Grand Prix  albert_park -37.84970
# 2      2010      3   2010_3      Malaysian Grand Prix       sepang   2.76083
# 3      2010      4   2010_4        Chinese Grand Prix     shanghai  31.33890
# 4      2010      5   2010_5        Spanish Grand Prix    catalunya  41.57000
# ..      ...    ...      ...                       ...          ...       ...
# 277    2023     19  2023_19  United States Grand Prix     americas  30.13280
# 278    2023     20  2023_20    Mexico City Grand Prix    rodriguez  19.40420
# 279    2023     21  2023_21      São Paulo Grand Prix   interlagos -23.70360
# 280    2023     22  2023_22      Las Vegas Grand Prix        vegas  36.11470
# 281    2023     23  2023_23      Abu Dhabi Grand Prix   yas_marina  24.46720
#
#       longitud        country       date  \
# ...

# %% [markdown]
# ## Drivers

# %%
drivers = {'driverId':[],
        'FirstName':[],
        'FamilyName':[],
        'DOB':[],
        'Nationality':[],
        'Biography':[]}


for year in list(range(2010,2024)):
    url = 'http://ergast.com/api/f1/{}/drivers.json?limit=1000'
    response = requests.get(url.format(year))
    content = json.loads(response.content)
    for item in content['MRData']['DriverTable']['Drivers']:
        drivers['driverId'].append(str(item['driverId']))
        drivers['FirstName'].append(str(item['givenName']))
        drivers['FamilyName'].append(str(item['familyName']))
        drivers['DOB'].append((item['dateOfBirth']))
        drivers['Nationality'].append(str(item['nationality']))
        drivers['Biography'].append(item['url'])

df = pd.DataFrame(drivers)
df = df.drop_duplicates(subset = ['driverId','FirstName','DOB'])
df.to_csv('DriversE1.csv', index = False)
df
# Out:
#         driverId  FirstName   FamilyName         DOB Nationality  \
# 0    alguersuari      Jaime  Alguersuari  1990-03-23     Spanish
# 1         alonso   Fernando       Alonso  1981-07-29     Spanish
# 2    barrichello     Rubens  Barrichello  1972-05-23   Brazilian
# 3          buemi  Sébastien        Buemi  1988-10-31       Swiss
# 4         button     Jenson       Button  1980-01-19     British
# ..           ...        ...          ...         ...         ...
# 279      tsunoda       Yuki      Tsunoda  2000-05-11    Japanese
# 285     de_vries       Nyck     de Vries  1995-02-06       Dutch
# 303         zhou     Guanyu         Zhou  1999-05-30     Chinese
# 316      piastri      Oscar      Piastri  2001-04-06  Australian
# 319     sargeant      Logan     Sargeant  2000-12-31    American
#
#                                              Biography
# 0       http://en.wikipedia.org/wiki/Jaime_Alguersuari
# 1         http://en.wikipedia.org/wiki/Fernando_Alonso
# ...

# %% [markdown]
# ## Constructors

# %%
constructors = {'constructorId':[],
        'Name':[],
        'Nationality':[],
        'url':[]}


for year in list(range(2010,2024)):
    url = 'http://ergast.com/api/f1/{}/constructors.json?limit=1000'
    response = requests.get(url.format(year))
    content = json.loads(response.content)
    for item in content['MRData']['ConstructorTable']['Constructors']:
        constructors['constructorId'].append(str(item['constructorId']))
        constructors['Name'].append(str(item['name']))
        constructors['Nationality'].append(str(item['nationality']))
        constructors['url'].append(item['url'])
    
df = pd.DataFrame(constructors)
df = df.drop_duplicates(subset = ['constructorId'])
pd.DataFrame(constructors).to_csv('ConstructorsE1.csv', index = False)
df
# Out:
#     constructorId            Name Nationality  \
# 0         ferrari         Ferrari     Italian
# 1     force_india     Force India      Indian
# 2             hrt             HRT     Spanish
# 3    lotus_racing           Lotus   Malaysian
# 4         mclaren         McLaren     British
# 5        mercedes        Mercedes      German
# 6        red_bull        Red Bull    Austrian
# 7         renault         Renault      French
# 8          sauber          Sauber       Swiss
# 9      toro_rosso      Toro Rosso     Italian
# 10         virgin          Virgin     British
# 11       williams        Williams     British
# 24       caterham        Caterham   Malaysian
# 28       lotus_f1        Lotus F1     British
# 29       marussia        Marussia     Russian
# 61          manor  Manor Marussia     British
# 70           haas    Haas F1 Team    American
# 99           alfa      Alfa Romeo       Swiss
# 104  racing_point    Racing Point     British
# ...

# %% [markdown]
# ## Circuits

# %%
circuits = {'circuitId':[],
        'CircuitName':[],
        'Locality':[],
        'Country':[],
        'Latitude':[],
        'Longitude':[],
        'url':[]}

for year in list(range(2010,2024)):
    url = 'http://ergast.com/api/f1/{}/circuits.json?limit=1000'
    response = requests.get(url.format(year))
    content = json.loads(response.content)
    for item in content['MRData']['CircuitTable']['Circuits']:
            circuits['circuitId'].append(str(item['circuitId']))
            circuits['CircuitName'].append(str(item['circuitName']))
            circuits['Locality'].append(str(item['Location'].get('locality')))
            circuits['Country'].append(str(item['Location'].get('country')))
            circuits['Latitude'].append(float(item['Location'].get('lat')))
            circuits['Longitude'].append(float(item['Location'].get('long')))
            circuits['url'].append(item['url'])

df = pd.DataFrame(circuits)
df = df.drop_duplicates(subset = ['circuitId'])
pd.DataFrame(constructors).to_csv('CircuitsE1.csv', index = False)
df
# Out:
#           circuitId                           CircuitName        Locality  \
# 0       albert_park        Albert Park Grand Prix Circuit       Melbourne
# 1           bahrain         Bahrain International Circuit          Sakhir
# 2         catalunya        Circuit de Barcelona-Catalunya        Montmeló
# 3    hockenheimring                        Hockenheimring      Hockenheim
# 4       hungaroring                           Hungaroring        Budapest
# 5        interlagos            Autódromo José Carlos Pace       São Paulo
# 6          istanbul                         Istanbul Park        Istanbul
# 7        marina_bay             Marina Bay Street Circuit      Marina Bay
# 8            monaco                     Circuit de Monaco     Monte-Carlo
# 9             monza          Autodromo Nazionale di Monza           Monza
# 10           sepang          Sepang International Circuit    Kuala Lumpur
# 11         shanghai        Shanghai International Circuit        Shanghai
# ...

# %% [markdown]
# ## Qualifying

# %%
qualifying = {'Year':[],
        'round':[],
        'raceId':[],
        'qualifyid':[],
        'RaceName':[],
        'driverId':[],     
        'Number':[],
        'Position':[],
        'constructorId':[],
        'Q1':[],
        'Q2':[],
        'Q3':[]}

urls = []

for i in list(range(2010,2024)):
    url1 = 'http://ergast.com/api/f1/'
    url2 = url1 + str(i)
    url3 = url2 + '.json'
    response = requests.get(url3)
    content = json.loads(response.content)
    for i in list(range(1,len(content['MRData']['RaceTable']['Races'])+1)):
        url4 = url2 + '/' +str(i) + '/qualifying.json' 
        urls.append(url4)
        
for j in urls:
    response = requests.get(j)
    content=json.loads(response.content)
    for m1 in content['MRData']['RaceTable']['Races']:
        for m2 in content['MRData']['RaceTable']['Races'][0]['QualifyingResults']:
            qualifying['Year'].append(int(m1['season']))
            qualifying['round'].append(int(m1['round']))
            qualifying['raceId'].append(m1['season'] + '_' + m1['round'])
            qualifying['qualifyid'].append('Qualifying' + '_'+ m1['season'] + '_' + m1['round'] )
            qualifying['RaceName'].append(str(m1['raceName']))
            qualifying['driverId'].append(str(m2['Driver'].get('driverId')))
            qualifying['Number'].append(int(m2['number']))
            qualifying['Position'].append(int(m2['position']))
            qualifying['constructorId'].append(str(m2['Constructor'].get('constructorId')))
            qualifying['Q1'].append(m2['Q1'])
            try:
                qualifying['Q2'].append(m2['Q2'])
            except:
                qualifying['Q2'].append('')
            try:
                qualifying['Q3'].append(m2['Q3'])
            except:
                qualifying['Q3'].append('')

df = pd.DataFrame(qualifying)
df.to_csv('Qualifying.csv', index =False)
df
